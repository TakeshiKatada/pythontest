# %%
print('Hello Jupyter!!')
# Out:
# Hello Jupyter!!

# %%
print('Hello Jupyter!!'
# Out:
#   File "<ipython-input-2-e7e3bca4872c>", line 1
#     print('Hello Jupyter!!'
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
your_name = 'Jupyter'

def hello(name):
    print('Hello {0} !!'.format(name))
    
hello(your_name)
# Out:
# Hello Jupyter !!

# %%
hello('notebook')
# Out:
# Hello notebook !!

# %%
import math

math.sqrt(4)
# Out:
# 2.0

# %%
math.sqrt?

# %%
your_name?

# %%
your_name
# Out:
# 'Jupyter'

# %% [markdown]
# #これは見出しです
#
# これは段落です。
#
# - 箇条書きも
# - このように表現できます。
#
# テーブルも記述できますね
#
# package|version
# -------|-------
# pandas|0.19.2
# matplotlib|2.0.0

# %%
# !cat /etc/hosts
# Out:
# ##
# # Host Database
# #
# # localhost is used to configure the loopback interface
# # when the system is booting.  Do not change this entry.
# ##
# 127.0.0.1	localhost
# 255.255.255.255	broadcasthost
# ::1             localhost

# %% [markdown]
# ## 数式の表示
#
#
# ¥begin{align}
# ¥sqrt{2x-1}+(3+x)^3$
# ¥end{align}
#
#
# $$E = mc^2$$
#
# インラインでも右記のように$¥sqrt{a^2 + b^2}$記述できます。

# %% [markdown]
# ## 画像
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202019-02-19%2011.02.40.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202019-02-19%2011.02.40.png)

# %%
# %pwd
# Out:
# '/Users/imac2/projects/notebooks'

# %%
working_dir = %pwd
working_dir
# Out:
# '/Users/imac2/projects/notebooks'

# %%
# %time sum(range(10000))
# Out:
# CPU times: user 230 µs, sys: 0 ns, total: 230 µs
# Wall time: 235 µs
# 49995000

# %%
# %timeit sum(range(10000))
# Out:
# 209 µs ± 3.33 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit -n 2000 -r 5 sum(range(10000))
# Out:
# 221 µs ± 8.21 µs per loop (mean ± std. dev. of 5 runs, 2000 loops each)

# %%
# %%timeit -n 1000 -r 3

for i in range(1000):
    i * 2
# Out:
# 72.6 µs ± 1.28 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)

# %%
# %history
sum(range(100))
sum(range(1000))
# Out:
# print('Hello Jupyter!!')
# print('Hello Jupyter!!'
# math.sqrt?
# your_name?
# your_name
# your_name = 'Jupyter'
#
# def hello(name):
#     print('Hello {0} !!'.format(name))
#
# hello(your_name)
# hello('notebook')
# import math
#
# math.sqrt(4)
# math.sqrt?
# your_name?
# your_name
# !cat /etc/hosts
# %pwd
# working_dir = %pwd
# working_dir
# %time sum(range(10000))
# %timeit sum(range(10000))
# %timeit -n 2000 -r 5 sum(range(10000))
# %%timeit -n 1000 -r 3
#
# for i in range(1000):
#     i * 2
# %history
# sum(range(100))
# sum(range(1000))
# 499500

# %%
# %ls
# Out:
# HelloJupyter.ipynb  Untitled.ipynb

# %%
# %autosave 130
# Out:
# Autosaving every 130 seconds

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,10,0.2)
y = np.sin(x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x,y)
plt.show()

# %%
# %matplotlib tk

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,10,0.2)
y = np.sin(x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x,y)
plt.show()

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,10,0.2)
y = np.sin(x)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x,y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 一度指定した出力方法の変更にはカーネルの再起動が必要
